# %% [markdown]
# ## Modelizacion de adjudicacion de proyectos de energia renovable en provincias de La Republica Argentina

# %% [markdown]
# ### Variable dependiente: provincia_tratada
# ### Variables independientes:
# 1. Variables de salario y empleo (RENOVAR)
# 2. Variables sociodemograficas y de pobreza (EPH)

# %% [markdown]
# # 1. Estadistica descriptiva

# %% [markdown]
# # 2. Modelo Logit

# %% [markdown]
# # 3. Random forest
